# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Sanjana Ramesh
# Software Developer

# %% [markdown]
# 100% Human

# %% [markdown]
#  _I'm interested in Data Science because I love to gain insights on data_

# %% [markdown]
# ### The Following are the test code for finding sum of two numbers

# %%
def sum(a , b):
    return a+b
sum(1,2)
# Out:
# 3

# %% [markdown]
# ![0.jpg](attachment:0.jpg)
#
# | Name | Age |
# | ----| ----|
# | Sanjana   | 24 |
# | Ramesh | 49 |
#
# Types of Machine Learning
# ***
#
# - Supervised Learning
# - Unsupervised Learning
# - Reinforcement Learning
